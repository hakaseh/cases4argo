# %%
import os.path
import datetime
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import netCDF4
from matplotlib import pyplot
from matplotlib import dates

import eatpy
from scipy.stats import qmc

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

setup_dir = "."
varname = "temp"

# %% [markdown]
# ### Define the parameter range and precision

# %%
# This file defines the parameter range and precision (decimal points) used for sensitivity analysis.
#
# Relevant files: fabm.yaml and generate_ensemble_yaml.py
#
# parameter_path: path to the parameter
# parameter_range: name, lower bound, upper bound, and decimal points for rounding

parameter_path = "instances/1p1z/parameters/"

parameter_range = [             
['I_thNH4',0.008,0.015,3],
['D_p5NH4',0.05,0.15,2],
['NitriR',0.01,0.5,2],
['K_NO3',0.5,5,1],
['K_NH4',0.5,5,1],
['Vp0',0.1,3.5,1],
['K_Phy',0.5,5.0,1],
#['PhyCN',6.625],
['PhyIS',0.007,0.13,3],
['PhyMR',0.01,0.25,2],
['Chl2C_m',0.005,0.15,3],
['ZooAE_N',0.25,0.95,2],
['ZooBM',0.01,0.35,2],
['ZooER',0.02,0.35,2],
['ZooGR',0.2,4.0,1],
['ZooMR',0.02,0.35,2],  
#['ZooCN',6.625], 
['LDeRRN',0.005,0.6,3], 
['SDeRRN',0.005,0.1,3],   
['CoagR',0.001,1,3], 
['wP',0.05,1.5,2],
['wL',0.5,10,1],
['wS',0.05,1.5,2], 
]

# %% [markdown]
# ### Generate an ensemble of fabm_####.yaml

# %%
N = 10    # ensemble size

# %%
name_para = [row[0] for row in parameter_range]
l_bounds = [row[1] for row in parameter_range]
u_bounds = [row[2] for row in parameter_range]
n_decimals = [row[3] for row in parameter_range]

D = len(name_para)     # parameter size
sampler = qmc.LatinHypercube(d=D)
sample = sampler.random(n=N)
sample_scaled = qmc.scale(sample, l_bounds, u_bounds)
sample_rounded = np.zeros_like(sample_scaled)
for i in range(np.shape(sample_scaled)[1]):
    sample_rounded[:,i] = np.round(sample_scaled[:,i],decimals=n_decimals[i])

with eatpy.models.gotm.YAMLEnsemble("gotm.yaml", N) as gotm, eatpy.models.gotm.YAMLEnsemble("fabm.yaml", N) as fabm:
# Commenting below will generate identical gotm_####.yaml files (do this if you want identical physics).
#    gotm["surface/u10/scale_factor"] = np.random.lognormal(sigma=0.1, size=N)
#    gotm["surface/v10/scale_factor"] = np.random.lognormal(sigma=0.1, size=N)
# Link each gotm_####.yaml to the corresponding fabm_####.yaml
    gotm["fabm/yaml_file"] = fabm.file_paths
# Set the MEMG model parameters
    #fabm["instances/1p1z/parameters/K_Phy"] *= np.random.lognormal(sigma=0.2, size=N)
    for i in range(len(name_para)):
        fabm[parameter_path+name_para[i]] = sample_rounded[:,i]
# Out:
# WARNING:root:fabm/yaml_file not present in template gotm.yaml
# INFO:root:Using template fabm.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.0095
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.1
# INFO:root:  instances/1p1z/parameters/NitriR: 0.05
# INFO:root:  instances/1p1z/parameters/K_NO3: 2.0
# INFO:root:  instances/1p1z/parameters/K_NH4: 2.0
# INFO:root:  instances/1p1z/parameters/Vp0: 0.69
# INFO:root:  instances/1p1z/parameters/K_Phy: 0.5
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.025
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.072
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.0535
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.75
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.1
# INFO:root:  instances/1p1z/parameters/ZooER: 0.1
# INFO:root:  instances/1p1z/parameters/ZooGR: 0.75
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.025
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.01
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.03
# INFO:root:  instances/1p1z/parameters/CoagR: 0.005
# INFO:root:  instances/1p1z/parameters/wP: 0.0
# INFO:root:  instances/1p1z/parameters/wL: 0.0
# INFO:root:  instances/1p1z/parameters/wS: 0.0
# INFO:root:Writing ./fabm_0001.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.01
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.06
# INFO:root:  instances/1p1z/parameters/NitriR: 0.31
# INFO:root:  instances/1p1z/parameters/K_NO3: 1.7
# INFO:root:  instances/1p1z/parameters/K_NH4: 3.8
# INFO:root:  instances/1p1z/parameters/Vp0: 0.9
# INFO:root:  instances/1p1z/parameters/K_Phy: 1.0
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.011
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.18
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.118
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.82
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.26
# INFO:root:  instances/1p1z/parameters/ZooER: 0.23
# INFO:root:  instances/1p1z/parameters/ZooGR: 3.9
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.03
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.538
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.024
# INFO:root:  instances/1p1z/parameters/CoagR: 0.233
# INFO:root:  instances/1p1z/parameters/wP: 1.0
# INFO:root:  instances/1p1z/parameters/wL: 7.1
# INFO:root:  instances/1p1z/parameters/wS: 1.15
# INFO:root:Writing ./fabm_0002.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.013
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.06
# INFO:root:  instances/1p1z/parameters/NitriR: 0.25
# INFO:root:  instances/1p1z/parameters/K_NO3: 4.2
# INFO:root:  instances/1p1z/parameters/K_NH4: 2.7
# INFO:root:  instances/1p1z/parameters/Vp0: 3.2
# INFO:root:  instances/1p1z/parameters/K_Phy: 3.1
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.11
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.15
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.064
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.9
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.08
# INFO:root:  instances/1p1z/parameters/ZooER: 0.13
# INFO:root:  instances/1p1z/parameters/ZooGR: 1.8
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.18
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.094
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.08
# INFO:root:  instances/1p1z/parameters/CoagR: 0.173
# INFO:root:  instances/1p1z/parameters/wP: 0.74
# INFO:root:  instances/1p1z/parameters/wL: 5.8
# INFO:root:  instances/1p1z/parameters/wS: 1.26
# INFO:root:Writing ./fabm_0003.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.015
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.14
# INFO:root:  instances/1p1z/parameters/NitriR: 0.17
# INFO:root:  instances/1p1z/parameters/K_NO3: 2.6
# INFO:root:  instances/1p1z/parameters/K_NH4: 0.9
# INFO:root:  instances/1p1z/parameters/Vp0: 2.5
# INFO:root:  instances/1p1z/parameters/K_Phy: 3.6
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.029
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.16
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.036
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.55
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.2
# INFO:root:  instances/1p1z/parameters/ZooER: 0.27
# INFO:root:  instances/1p1z/parameters/ZooGR: 0.7
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.19
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.373
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.037
# INFO:root:  instances/1p1z/parameters/CoagR: 0.769
# INFO:root:  instances/1p1z/parameters/wP: 0.34
# INFO:root:  instances/1p1z/parameters/wL: 2.3
# INFO:root:  instances/1p1z/parameters/wS: 0.66
# INFO:root:Writing ./fabm_0004.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.013
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.07
# INFO:root:  instances/1p1z/parameters/NitriR: 0.1
# INFO:root:  instances/1p1z/parameters/K_NO3: 2.1
# INFO:root:  instances/1p1z/parameters/K_NH4: 3.3
# INFO:root:  instances/1p1z/parameters/Vp0: 2.2
# INFO:root:  instances/1p1z/parameters/K_Phy: 3.8
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.119
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.03
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.095
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.45
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.06
# INFO:root:  instances/1p1z/parameters/ZooER: 0.16
# INFO:root:  instances/1p1z/parameters/ZooGR: 2.5
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.11
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.283
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.016
# INFO:root:  instances/1p1z/parameters/CoagR: 0.658
# INFO:root:  instances/1p1z/parameters/wP: 0.55
# INFO:root:  instances/1p1z/parameters/wL: 1.4
# INFO:root:  instances/1p1z/parameters/wS: 0.86
# INFO:root:Writing ./fabm_0005.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.009
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.11
# INFO:root:  instances/1p1z/parameters/NitriR: 0.01
# INFO:root:  instances/1p1z/parameters/K_NO3: 1.1
# INFO:root:  instances/1p1z/parameters/K_NH4: 1.2
# INFO:root:  instances/1p1z/parameters/Vp0: 0.3
# INFO:root:  instances/1p1z/parameters/K_Phy: 1.5
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.076
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.05
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.016
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.48
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.23
# INFO:root:  instances/1p1z/parameters/ZooER: 0.05
# INFO:root:  instances/1p1z/parameters/ZooGR: 0.3
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.26
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.325
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.084
# INFO:root:  instances/1p1z/parameters/CoagR: 0.452
# INFO:root:  instances/1p1z/parameters/wP: 1.27
# INFO:root:  instances/1p1z/parameters/wL: 8.5
# INFO:root:  instances/1p1z/parameters/wS: 0.53
# INFO:root:Writing ./fabm_0006.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.011
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.12
# INFO:root:  instances/1p1z/parameters/NitriR: 0.41
# INFO:root:  instances/1p1z/parameters/K_NO3: 3.7
# INFO:root:  instances/1p1z/parameters/K_NH4: 4.4
# INFO:root:  instances/1p1z/parameters/Vp0: 1.5
# INFO:root:  instances/1p1z/parameters/K_Phy: 2.0
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.054
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.11
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.059
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.8
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.3
# INFO:root:  instances/1p1z/parameters/ZooER: 0.08
# INFO:root:  instances/1p1z/parameters/ZooGR: 1.1
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.14
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.194
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.054
# INFO:root:  instances/1p1z/parameters/CoagR: 0.936
# INFO:root:  instances/1p1z/parameters/wP: 0.07
# INFO:root:  instances/1p1z/parameters/wL: 3.2
# INFO:root:  instances/1p1z/parameters/wS: 0.24
# INFO:root:Writing ./fabm_0007.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.014
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.1
# INFO:root:  instances/1p1z/parameters/NitriR: 0.47
# INFO:root:  instances/1p1z/parameters/K_NO3: 3.4
# INFO:root:  instances/1p1z/parameters/K_NH4: 2.8
# INFO:root:  instances/1p1z/parameters/Vp0: 0.7
# INFO:root:  instances/1p1z/parameters/K_Phy: 0.8
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.093
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.09
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.132
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.72
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.11
# INFO:root:  instances/1p1z/parameters/ZooER: 0.1
# INFO:root:  instances/1p1z/parameters/ZooGR: 3.3
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.06
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.461
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.047
# INFO:root:  instances/1p1z/parameters/CoagR: 0.868
# INFO:root:  instances/1p1z/parameters/wP: 1.41
# INFO:root:  instances/1p1z/parameters/wL: 10.0
# INFO:root:  instances/1p1z/parameters/wS: 0.14
# INFO:root:Writing ./fabm_0008.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.011
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.14
# INFO:root:  instances/1p1z/parameters/NitriR: 0.36
# INFO:root:  instances/1p1z/parameters/K_NO3: 5.0
# INFO:root:  instances/1p1z/parameters/K_NH4: 1.8
# INFO:root:  instances/1p1z/parameters/Vp0: 1.2
# INFO:root:  instances/1p1z/parameters/K_Phy: 4.3
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.099
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.21
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.079
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.66
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.04
# INFO:root:  instances/1p1z/parameters/ZooER: 0.21
# INFO:root:  instances/1p1z/parameters/ZooGR: 2.3
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.31
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.181
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.01
# INFO:root:  instances/1p1z/parameters/CoagR: 0.316
# INFO:root:  instances/1p1z/parameters/wP: 0.89
# INFO:root:  instances/1p1z/parameters/wL: 7.6
# INFO:root:  instances/1p1z/parameters/wS: 0.38
# INFO:root:Writing ./fabm_0009.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.012
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.11
# INFO:root:  instances/1p1z/parameters/NitriR: 0.13
# INFO:root:  instances/1p1z/parameters/K_NO3: 0.7
# INFO:root:  instances/1p1z/parameters/K_NH4: 2.2
# INFO:root:  instances/1p1z/parameters/Vp0: 1.9
# INFO:root:  instances/1p1z/parameters/K_Phy: 2.6
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.038
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.23
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.145
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.33
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.15
# INFO:root:  instances/1p1z/parameters/ZooER: 0.29
# INFO:root:  instances/1p1z/parameters/ZooGR: 1.6
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.22
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.544
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.07
# INFO:root:  instances/1p1z/parameters/CoagR: 0.597
# INFO:root:  instances/1p1z/parameters/wP: 0.2
# INFO:root:  instances/1p1z/parameters/wL: 4.3
# INFO:root:  instances/1p1z/parameters/wS: 1.0
# INFO:root:Writing ./fabm_0010.yaml...
# INFO:root:  instances/1p1z/parameters/I_thNH4: 0.008
# INFO:root:  instances/1p1z/parameters/D_p5NH4: 0.09
# INFO:root:  instances/1p1z/parameters/NitriR: 0.28
# INFO:root:  instances/1p1z/parameters/K_NO3: 3.0
# INFO:root:  instances/1p1z/parameters/K_NH4: 4.6
# INFO:root:  instances/1p1z/parameters/Vp0: 3.1
# INFO:root:  instances/1p1z/parameters/K_Phy: 4.8
# INFO:root:  instances/1p1z/parameters/PhyIS: 0.066
# INFO:root:  instances/1p1z/parameters/PhyMR: 0.06
# INFO:root:  instances/1p1z/parameters/Chl2C_m: 0.024
# INFO:root:  instances/1p1z/parameters/ZooAE_N: 0.25
# INFO:root:  instances/1p1z/parameters/ZooBM: 0.32
# INFO:root:  instances/1p1z/parameters/ZooER: 0.34
# INFO:root:  instances/1p1z/parameters/ZooGR: 3.1
# INFO:root:  instances/1p1z/parameters/ZooMR: 0.33
# INFO:root:  instances/1p1z/parameters/LDeRRN: 0.043
# INFO:root:  instances/1p1z/parameters/SDeRRN: 0.093
# INFO:root:  instances/1p1z/parameters/CoagR: 0.037
# INFO:root:  instances/1p1z/parameters/wP: 1.19
# INFO:root:  instances/1p1z/parameters/wL: 5.0
# INFO:root:  instances/1p1z/parameters/wS: 1.48
# INFO:root:Using template gotm.yaml...
# INFO:root:  fabm/yaml_file: NOT PRESENT
# INFO:root:Writing ./gotm_0001.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0001.yaml
# INFO:root:Writing ./gotm_0002.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0002.yaml
# INFO:root:Writing ./gotm_0003.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0003.yaml
# INFO:root:Writing ./gotm_0004.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0004.yaml
# INFO:root:Writing ./gotm_0005.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0005.yaml
# INFO:root:Writing ./gotm_0006.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0006.yaml
# INFO:root:Writing ./gotm_0007.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0007.yaml
# INFO:root:Writing ./gotm_0008.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0008.yaml
# INFO:root:Writing ./gotm_0009.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0009.yaml
# INFO:root:Writing ./gotm_0010.yaml...
# INFO:root:  fabm/yaml_file: ./fabm_0010.yaml

# %% [markdown]
# ### Run an ensemble of sensivity simulations

# %%
# !mpiexec -n 1 python run_sensitivity.py : -n {N} eat-gotm --separate_gotm_yaml
# Out:
# INFO:root:Model simulated period: 1998-01-01 00:00:00 - 1999-01-01 00:00:00
# INFO:root:The filter will affect the following 27 state variables:
# INFO:root:  temp: potential temperature (Celsius) [110 values, 0:110 in model]
# INFO:root:  salt: salinity (g/kg) [110 values, 110:220 in model]
# INFO:root:  u: x-velocity (m/s) [110 values, 220:330 in model]
# INFO:root:  uo: x-velocity - old time step (m/s) [110 values, 330:440 in model]
# INFO:root:  v: y-velocity (m/s) [110 values, 440:550 in model]
# INFO:root:  vo: y-velocity - old time step (m/s) [110 values, 550:660 in model]
# INFO:root:  u_taubo: bottom friction velocity - old time step (m/s) [1 values, 660:661 in model]
# INFO:root:  xP: extra turbulence production (m2/s3) [110 values, 661:771 in model]
# INFO:root:  h: layer thickness (m) [110 values, 771:881 in model]
# INFO:root:  ho: layer thickness - old time step (m) [110 values, 881:991 in model]
# INFO:root:  num: turbulent diffusivity of momentum (m2/s) [111 values, 991:1102 in model]
# INFO:root:  nuh: turbulent diffusivity of heat (m2/s) [111 values, 1102:1213 in model]
# INFO:root:  nus: turbulent diffusivity of salt (m2/s) [111 values, 1213:1324 in model]
# INFO:root:  tke: turbulent kinetic energy (m2/s2) [111 values, 1324:1435 in model]
# INFO:root:  tkeo: turbulent kinetic energy - old time step (m2/s2) [111 values, 1435:1546 in model]
# INFO:root:  eps: energy dissipation rate (m2/s3) [111 values, 1546:1657 in model]
# INFO:root:  1p1z_no3: 1p1z nitrate (mmol N m-3) [110 values, 1657:1767 in model]
# INFO:root:  1p1z_nh4: 1p1z ammonia (mmol N m-3) [110 values, 1767:1877 in model]
# INFO:root:  1p1z_phy: 1p1z phytoplankton (mmol N m-3) [110 values, 1877:1987 in model]
# INFO:root:  1p1z_chl: 1p1z chlorophyll (mg m-3) [110 values, 1987:2097 in model]
# INFO:root:  1p1z_zoo: 1p1z zooplankton (mmol N m-3) [110 values, 2097:2207 in model]
# INFO:root:  1p1z_LDeN: 1p1z LdetritusN (mmol N m-3) [110 values, 2207:2317 in model]
# INFO:root:  1p1z_SDeN: 1p1z SdetritusN (mmol N m-3) [110 values, 2317:2427 in model]
# INFO:root:  lon: longitude (degrees_east) [1 values, 2427:2428 in model]
# INFO:root:  lat: latitude (degrees_north) [1 values, 2428:2429 in model]
# INFO:root:  z: depth (m) [110 values, 2429:2539 in model]
# INFO:root:  zi: interface depth (m) [111 values, 2539:2650 in model]
#
# PDAF    ++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PDAF    +++                      PDAF                      +++
# PDAF    +++      Parallel Data Assimilation Framework      +++
# PDAF    +++                                                +++
# PDAF    +++             Version 1.16 VAR devel             +++
# PDAF    +++                                                +++
# PDAF    +++   Please cite Nerger and Hiller (2013) when    +++
# PDAF    +++   publishing work resulting from using PDAF    +++
# PDAF    ++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# INFO:root:No more observations to assimilate
# INFO:root:Finalizing plugins...
# INFO:root:Waiting for ensemble members to finish forecast-only remainder of the simulation...
# Abort(812222607): Fatal error in internal_Finalize: Other MPI error, error stack:
# internal_Finalize(48002).........: MPI_Finalize failed
# MPII_Finalize(421)...............:
# MPID_Finalize(775)...............:
# MPIDI_OFI_mpi_finalize_hook(1081):
# flush_send_queue(1040)...........:
# MPIDI_OFI_handle_cq_error(793)...: OFI poll failed (ofi_events.c:793:MPIDI_OFI_handle_cq_error:Input/output error)
#
# ===================================================================================
# =   BAD TERMINATION OF ONE OF YOUR APPLICATION PROCESSES
# =   PID 96054 RUNNING AT Hakases-MacBook-Pro.local
# =   EXIT CODE: 9
# =   CLEANING UP REMAINING PROCESSES
# =   YOU CAN IGNORE THE BELOW CLEANUP MESSAGES
# ===================================================================================
# YOUR APPLICATION TERMINATED WITH THE EXIT STRING: Killed: 9 (signal 9)
# This typically refers to a problem with your application.
# Please see the FAQ page for debugging suggestions

# %%
# Read satellite observations of sea surface temperature
obs = []
if varname == 'temp':
    for l in open(os.path.join(setup_dir, 'cci_sst_delete.dat')):
        if not l.startswith('#'):
            dt, value, sd = l.rstrip().split('\t')
            obs.append([datetime.datetime.strptime(dt, '%Y-%m-%d %H:%M:%S'), float(value), float(sd)])
obs = np.array(obs).reshape(-1, 3)

# %%
#pyplot.plot
(obs[:,0])
# Out:
# array([datetime.datetime(1982, 1, 1, 12, 0),
#        datetime.datetime(1982, 1, 10, 12, 0),
#        datetime.datetime(1982, 1, 20, 12, 0), ...,
#        datetime.datetime(2020, 12, 29, 12, 0),
#        datetime.datetime(2020, 12, 30, 12, 0),
#        datetime.datetime(2020, 12, 31, 12, 0)], dtype=object)

# %% [markdown]
# ## Plot default GOTM results
#
# Forecast-only, no data assimilation

# %%
nc = netCDF4.Dataset(os.path.join(setup_dir, 'result.nc'))

time = netCDF4.num2date(nc['time'], nc['time'].units)
mpltime = dates.date2num(time)
z = nc['z'][:, :, 0, 0]
temp = nc[varname][:, :, 0, 0]
sst = temp[:, -1]

fig, (ax1, ax2) = pyplot.subplots(figsize=(8,8), nrows=2)

ax1.plot_date(obs[:,0], obs[:,1], '.', label='satellite')
ax1.plot_date(mpltime, sst, '-', label='model')
ax1.set_xlim(mpltime[0], mpltime[-1])
ax1.set_ylabel('temperature (\u00b0C)')
ax1.grid()
ax1.legend()
ax1.set_title('sea surface temperature')

mpltime_2d = np.broadcast_to(mpltime[:, np.newaxis], z.shape)
pc = ax2.contourf(mpltime_2d, z, temp)
cb = fig.colorbar(pc, ax=ax2)
cb.set_label('potential temperature (\u00b0C)')
ax2.set_ylabel('height (m)')
ax2.set_title('water temperature')
ax2.xaxis.axis_date()

# %% [markdown]
# ## Plot ensemble GOTM results

# %%
N = 4
ncs = [netCDF4.Dataset(os.path.join(setup_dir, 'result_%04i.nc' % (i + 1))) for i in range(N)]

enstime = netCDF4.num2date(ncs[0]['time'], ncs[0]['time'].units)
ensmpltime = dates.date2num(enstime)
z = ncs[0].variables['z'][:, :, 0, 0]
temps = [nc[varname][:, :, 0, 0] for nc in ncs]
ssts = [temp[:, -1] for temp in temps]

fig, (ax1, ax2) = pyplot.subplots(figsize=(8,12), nrows=2)
ax1.plot_date(obs[:,0], obs[:,1], '.', label='satellite')
ax1.plot_date(time, sst, '-', label='model, no DA')
ax1.plot_date(enstime, np.mean(ssts, axis=0), '-', label='model, DA')
ax1.set_xlim(time[0], time[-1])
ax1.set_ylabel('temperature (\u00b0C)')
ax1.grid()
ax1.legend()
ax1.set_title('sea surface temperature')

mpltime_2d = np.broadcast_to(ensmpltime[:, np.newaxis], z.shape)
temp_diff = np.mean(temps, axis=0) - temp[-enstime.size:, :]
pc = ax2.contourf(mpltime_2d, z, temp_diff, cmap='RdBu_r', levels=np.linspace(-1.,1.,21), extend='both')
cb = fig.colorbar(pc, ax=ax2)
cb.set_label('temperature difference (\u00b0C)')
ax2.set_ylabel('height (m)')
ax2.set_title('water temperature difference (DA - no DA)');
ax2.xaxis.axis_date()
